# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import sys
import pandas as pd
# import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
# plt.style.use('seaborn-poster')

# %%
files = ["exp2.csv", "exp5.csv", "exp10.csv"]

frames = [df2, df5, df10]
df2 = pd.read_csv(files[0]).groupby("nodos").mean()
df2 = df2.rename(columns={'conflictos': 'dificultad=2'})
df5 = pd.read_csv(files[1]).groupby("nodos").mean()
df2["dificultad=5"] = df5["conflictos"]
df10 = pd.read_csv(files[2]).groupby("nodos").mean()
df2["dificultad=10"] = df10["conflictos"]

df2.plot.bar().set_ylabel("conflictos")

plt.show()
